# %% [markdown]
# # Recognise numbers in images
# ## Data Structures and alogrithms
# **Hogeschool Rotterdam**\
# **Dani Jurjevic**\
# **Rein Schregardus**

# %%
import scripts.randompythonfile as randompythonfile

print(randompythonfile.return10())
# Out:
# 10
