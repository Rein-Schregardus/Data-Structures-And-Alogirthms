# %% [markdown]
# ## Project
#
# Experimenteer met jupyter notebook en laad mnist db
#
# ### Leerdoelen
#
# - MNIST laden in Jupyter
#
# - Afbeeldingen bekijken
#
# - Data beschrijven i.p.v. alleen “gebruiken”
#
# - Kritisch nadenken over ML-problemen

# %% [markdown]
# ### Rapportage
#
# Zorg er voor dat de groepjes uit (max) 2 mensen bestaan.
#
# Elk groepje moet de volgende onderwerpen uitwerken. Enkele groepjes worden volgende lesweek uitgekozen om het te presenteren.
#
# De gemaakte ipynb en de discussie/feedback op de eventuele presentatie moeten worden uitgewerkt en in de rapportage van het team opgeslagen op CodeGrade onder **P1 Onderzoek van de database**

# %% [markdown]
# ## 1. Dataset-verkenning
#
# Doel: leren wat “een dataset” eigenlijk is
#
# **Vragen**
#
# Maak code om het volgende te bepalen:
#
# - Hoeveel afbeeldingen bevat MNIST?
#
# - Hoeveel voorbeelden zijn er per cijfer (0–9)?
#
# - Is de dataset gebalanceerd?
#
# - Welk cijfer komt het meest voor?
#
# - Welk het minst?
#
# - Hoe groot is één afbeelding (vorm en datatype)?

# %% [markdown]
# ## 2 Visuele analyse van cijfers
#
# Doel: begrijpen waarom classificatie lastig is
#
# **Vragen**
#
# - Laat 5 willekeurige voorbeelden zien van éénzelfde cijfer (bijv. 3).
#
# - Wat valt op?
#
# - Welke cijfers lijken visueel sterk op elkaar?
#
# - Zijn sommige cijfers “slordiger” geschreven dan andere?
#
# - Vergelijk bijv. 4 en 9, of 1 en 7
#
# Presentatie-output
# - Afbeeldingen
# - Observaties

# %% [markdown]
# ## 3. Pixelstatistieken (eerste stap richting features)
#
# Doel: laten zien dat pixels data zijn, geen plaatjes
#
# **Vragen**
#
# Maak code om het volgende te bepalen:
#
# Wat is de gemiddelde pixelwaarde van:
#
# - alle afbeeldingen samen?
#
# - één specifiek cijfer?
#
# - Welke pixels zijn gemiddeld het “lichtst” of “donkerst”?
#
# - Kun je het gemiddelde beeld van een cijfer maken?
#
# Presentatie-output
# - Eén “average digit” per groep
# - Wat zien we eigenlijk volgens jou?

# %% [markdown]
# ## 4. Reflectievragen
#
# Doel: ML-denken stimuleren
#
# **Vragen**
#
# - Welke informatie gebruikt een mens om cijfers te herkennen?
#
# - Welke informatie krijgt een computer wel en niet?
#
# - Denk je dat alleen pixels genoeg zijn?
#
# - Waarom is MNIST populair als oefendataset?
#
# Presentatie-output
# - Discussie
# - Geen code vereist

# %% [markdown]
# ## 5. Data-kwaliteit & moeilijkheid
#
# Doel: kritisch denken over datasets
#
# **Vragen**
#
# - Zijn alle afbeeldingen duidelijk leesbaar?
#
# - Kun je voorbeelden vinden die zelf moeilijk te herkennen zijn?
#
# - Welke cijfers zouden volgens jullie het lastigst zijn voor een computer en waarom?
#
# Presentatie-output
# - “Moeilijke” voorbeelden
#
# - Argumentatie
